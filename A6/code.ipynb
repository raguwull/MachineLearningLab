# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/ragulb/Library/Python/3.9/lib/python/site-packages (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ragulb/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/ragulb/Library/Python/3.9/lib/python/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ragulb/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/ragulb/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

filepath = os.getenv('FILE_PATH')
data = pd.read_csv(filepath)

data = data.drop(columns=['subject', 'Activity'])

scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

k = 6

kmeans = KMeans(n_clusters=k, random_state=42)

kmeans.fit(data_scaled)

cluster_centers = kmeans.cluster_centers_

cluster_labels = kmeans.labels_

data['Cluster'] = cluster_labels

from sklearn.decomposition import PCA

pca = PCA(n_components=2)
data_pca = pca.fit_transform(data_scaled)

plt.figure(figsize=(10, 6))
plt.scatter(data_pca[:, 0], data_pca[:, 1], c=cluster_labels, cmap='viridis', s=50, alpha=0.5)
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='red', marker='x', s=100)
plt.title('KMeans Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster')
plt.show()
